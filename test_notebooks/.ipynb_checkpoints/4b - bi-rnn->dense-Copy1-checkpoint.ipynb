# %%
import numpy as np
import pandas as pd
import tensorflow as tf

tf.enable_eager_execution()
tf.set_random_seed(230)
print(tf.__version__)

from matplotlib import pyplot as plt

import time
import sys
sys.path.append('..')
# Out:
# 1.12.0

# %%
from configs.rnn_prodn import hparams
hparams = hparams()
print(hparams)
# Out:
# [('batch_size', 800), ('datagen', 'prodn'), ('in_seq_len', 61), ('input_channels', 1), ('input_dim', 5), ('lambd', 1e-06), ('learning_rate', 0.01), ('logs_path', '/tmp/tensorflow_logs'), ('lr_decay', 0.99), ('neurons_unit', 32), ('norm_epsilon', 1e-12), ('num_layers', 1), ('out_seq_len', 61), ('output_channels', 1), ('output_dim', 1), ('test_split', 0.1), ('train_split', 0.8), ('val_split', 0.1)]

# %% [markdown]
# ### Define Data Generator

# %%
from data_loader.prodn import *
get_fields = 'mini'
dataset, dataset_val, dataset_test = load_data(hparams, mode=get_fields)
# Out:
# (14470, 1000)
# Loading Data - Mode: mini

# %% [markdown]
# ### Define Model

# %%
class RNN(tf.keras.Model):
    def __init__(self, output_dim, units, batch_size, dropout_rate=0.2):
        super(RNN, self).__init__()
        self.units = units
        self.output_dim = output_dim
        self.dropout_rate = dropout_rate
        self.batch_sz = batch_size
        self.training = True
        
        if tf.test.is_gpu_available():
            self.gru = tf.keras.layers.Bidirectional(\
                            tf.keras.layers.CuDNNGRU(self.units, return_sequences=True, return_state=True, name='gru'))
        else:
            self.gru = tf.keras.layers.Bidirectional(\
                            tf.keras.layers.GRU(self.units, return_sequences=True, return_state=True, 
                                                   recurrent_activation='relu', name='gru'))

        self.dropout = tf.keras.layers.Dropout(self.dropout_rate)

        self.fc_out = tf.keras.layers.Dense(self.output_dim, activation='relu', name='affine_out')

    def call(self, x, mask):
        
        xr = tf.reverse(x, [1])
        x  = tf.concat([x, xr], axis=2)
        output, states, _ = self.gru(xr, initial_state=self.reset_states())

        x = self.fc_out(self.dropout(output, training=self.training))
        x *= mask

        return x

# %% [markdown]
# ### Train Model

# %%
loss, accuracy, run_time, stats = trainer.train_model(model, optimizer, dataset, hparams,
                                                      epochs=1, verbose=True, dev_dataset=None)
# Out:
# Epoch 1 Loss 0.0009 Accuracy 0.0008
# Time taken for 1 epoch 19.3205 sec

# %%
import trainers.tf_eager_trainer as trainer

# Run a training batch
tf.set_random_seed(231) # Set seed

# Initialise model and optimiser
model = RNN(hparams.output_dim, hparams.neurons_unit, hparams.batch_size)
optimizer = tf.train.AdamOptimizer(learning_rate = hparams.learning_rate)

# Start training run
loss, accuracy, run_time, stats = trainer.train_model(model, optimizer, dataset_, hparams,
                                                      epochs=20, verbose=True, dev_dataset=None)

# Display results
print('Loss {:.4f} Accuracy {:.4f} Time {:.4f}'.format(loss * 100, accuracy * 100, run_time))

plt.figure()
for name, stat in stats.items():
    if name != 'time':
        plt.plot(stat, label=name)
plt.legend()
plt.yscale('log')
plt.show()

#trainer.save_model(model, optimizer, dataset_val, hparams, 'birnn_affine_' + get_fields.replace(' ', '_'), stats=stats)
model.summary()
# Out:
# Epoch 1 Loss 0.0028 Accuracy 0.0024
# Time taken for 1 epoch 18.4439 sec
#
# Epoch 2 Loss 0.0017 Accuracy 0.0013
# Time taken for 1 epoch 18.1967 sec
#
# Epoch 3 Loss 0.0015 Accuracy 0.0012
# Time taken for 1 epoch 18.1546 sec
#
# Epoch 4 Loss 0.0014 Accuracy 0.0011
# Time taken for 1 epoch 18.2049 sec
#
# Epoch 5 Loss 0.0013 Accuracy 0.0011
# Time taken for 1 epoch 18.2111 sec
#
# Epoch 6 Loss 0.0012 Accuracy 0.0010
# Time taken for 1 epoch 18.2024 sec
#
# Epoch 7 Loss 0.0012 Accuracy 0.0010
# Time taken for 1 epoch 18.1375 sec
#
# Epoch 8 Loss 0.0011 Accuracy 0.0010
# Time taken for 1 epoch 18.4273 sec
#
# Epoch 9 Loss 0.0011 Accuracy 0.0009
# Time taken for 1 epoch 18.1064 sec
#
# Epoch 10 Loss 0.0011 Accuracy 0.0009
# Time taken for 1 epoch 18.1946 sec
#
# Epoch 11 Loss 0.0011 Accuracy 0.0009
# Time taken for 1 epoch 18.0861 sec
#
# Epoch 12 Loss 0.0010 Accuracy 0.0009
# Time taken for 1 epoch 18.8735 sec
#
# Epoch 13 Loss 0.0010 Accuracy 0.0009
# Time taken for 1 epoch 18.0445 sec
#
# Epoch 14 Loss 0.0010 Accuracy 0.0008
# Time taken for 1 epoch 18.0278 sec
#
# Epoch 15 Loss 0.0009 Accuracy 0.0008
# Time taken for 1 epoch 18.0890 sec
#
# Epoch 16 Loss 0.0009 Accuracy 0.0008
# Time taken for 1 epoch 18.0357 sec
#
# Epoch 17 Loss 0.0009 Accuracy 0.0008
# Time taken for 1 epoch 18.0189 sec
#
# Epoch 18 Loss 0.0009 Accuracy 0.0008
# Time taken for 1 epoch 18.0552 sec
#
# Epoch 19 Loss 0.0009 Accuracy 0.0007
# Time taken for 1 epoch 17.9900 sec
#
# Epoch 20 Loss 0.0009 Accuracy 0.0007
# Time taken for 1 epoch 18.0940 sec
#
# Loss 0.0009 Accuracy 0.0007 Time 363.5956
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_67 (Bidirectio multiple                  103680
# _________________________________________________________________
# dropout_67 (Dropout)         multiple                  0
# _________________________________________________________________
# affine_out (Dense)           multiple                  257
# =================================================================
# Total params: 103,937
# Trainable params: 103,937
# Non-trainable params: 0
# _________________________________________________________________

# %%
# show all sequences
# Select target sequence to show
TARGET_INDEX = 0

# Create forecast and rescale data
inp, target, mask, x_max = next(iter(dataset))
model.training = False
forecast = model(inp, mask)
forecast *= tf.keras.backend.expand_dims(x_max)
target   *= tf.keras.backend.expand_dims(x_max)
inp = np.reshape(inp, [hparams.batch_size, hparams.in_seq_len, hparams.input_dim, hparams.input_channels])
inp *= np.reshape(x_max, [hparams.batch_size,1,1,-1])

# Plot target sequence
plt.figure(figsize=(16,12))
plt.plot(np.squeeze(forecast[TARGET_INDEX,:,0]), label='forecast')
plt.plot(np.squeeze(target[TARGET_INDEX,:,0]), label='target')
plt.plot(np.mean(inp, axis=2)[TARGET_INDEX,:,0], 'bo', label='5 period average')
for i in range(hparams.input_dim):
    plt.plot(np.array(inp)[TARGET_INDEX,:,i,0], '--', label='%i periods prior' % (5-i))
plt.legend()
plt.show()

# Plot specimen predictions
plt.figure(figsize=(16,16))
for i in range(0,100):
    ax = plt.subplot(10,10,i+1)
    ax.plot(np.squeeze(forecast[i]), label='forecast')
    ax.plot(np.squeeze(target[i]), label='target')
plt.show()

# %% [markdown]
# ### Test Hyperparameters

# %%
np.random.seed(231)
models = []

#for nodes in np.floor(2 ** np.arange(3,9)):
#for lr in np.random.uniform(-8, -1, 10):
for lr in range(-8, 0, 1):
    lr /= 2

    # Run a training batch
    tf.set_random_seed(231) # Set seed

    # Initialise model and optimiser
    model_ = RNN(hparams.output_dim, hparams.neurons_unit, hparams.batch_size)
    optimizer_ = tf.train.AdamOptimizer(learning_rate = 10 ** lr)

    # Start training run
    loss, accuracy, run_time, stats = trainer.train_model(model_, optimizer_, dataset, hparams,
                                                          epochs=50, verbose=False, dev_dataset=None)
    print('Learning Rate {:.4f} Loss {:.4f} Accuracy {:.4f} Time {:.1f}'.format(lr, loss*100, accuracy * 100, run_time))
    
    models.append(model_)
# Out:
# Learning Rate -4.0000 Loss 0.0038 Accuracy 0.0036 Time 4.7
# Learning Rate -3.5000 Loss 0.0018 Accuracy 0.0016 Time 4.8
# Learning Rate -3.0000 Loss 0.0014 Accuracy 0.0012 Time 4.9
# Learning Rate -2.5000 Loss 0.0010 Accuracy 0.0009 Time 4.8
# Learning Rate -2.0000 Loss 0.0152 Accuracy 0.0150 Time 4.9
# Learning Rate -1.5000 Loss 0.0158 Accuracy 0.0150 Time 4.8
# Learning Rate -1.0000 Loss 0.0276 Accuracy 0.0150 Time 4.9
# Learning Rate -0.5000 Loss 0.1174 Accuracy 0.0153 Time 4.8

# %% [markdown]
# ## Test Model Accuracy

# %%
model_accuracy = []

# %%
START_POINT = 0
total_accuracy = []
x_variance = x_var(hparams, mode=get_fields, normalise='local_max_min')

for i, (inp, target, mask, x_max) in enumerate(dataset):
    forecast = model(inp, mask)

    accuracy = tf.squeeze(forecast - target) * x_max
    accuracy = accuracy ** 2 / x_variance
    accuracy = np.mean(accuracy, axis=0)
    
    total_accuracy.append(accuracy)

model_accuracy.append((hparams.in_seq_len, np.mean(total_accuracy, axis=0)))
    
print('Total Accuracy: %.4f' % np.mean(total_accuracy))
plt.plot(np.mean(total_accuracy, axis=0))
plt.show()
# Out:
# Total Accuracy: 0.1814
