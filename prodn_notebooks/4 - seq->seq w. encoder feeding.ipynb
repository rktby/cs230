# %%
import numpy as np
import pandas as pd
import tensorflow as tf

tf.enable_eager_execution()
tf.set_random_seed(230)
print(tf.__version__)

from matplotlib import pyplot as plt

import time
import sys
sys.path.append('..')
# Out:
# 1.12.0

# %%
from configs.rnn_biogas import hparams
hparams = hparams()
print(hparams)
# Out:
# [('batch_size', 800), ('datagen', 'biogas'), ('in_seq_len', 24), ('input_channels', 1), ('input_dim', 5), ('lambd', 1e-06), ('learning_rate', 0.01), ('logs_path', '/tmp/tensorflow_logs'), ('lr_decay', 0.99), ('neurons_unit', 32), ('norm_epsilon', 1e-12), ('num_layers', 1), ('out_seq_len', 24), ('output_channels', 1), ('output_dim', 1), ('test_split', 0.1), ('train_split', 0.8), ('val_split', 0.1)]

# %% [markdown]
# ### Define Data Generator

# %%
from data_loader.biogas import *
get_fields = 'AT305'
dataset, dataset_val, dataset_test = load_data(hparams, mode=get_fields)

# %% [markdown]
# ### Define Model

# %%
class RNN(tf.keras.Model):
    def __init__(self, output_dim, units, batch_size, dropout_rate=0.2):
        super(RNN, self).__init__()
        self.units = units
        self.output_dim = output_dim
        self.dropout_rate = dropout_rate
        self.batch_sz = batch_size
        self.training = True

        
        if tf.test.is_gpu_available():
            self.encoder = tf.keras.layers.CuDNNGRU(self.units, return_sequences=True,
                                                    return_state=True, name='encoder')
            self.decoder = tf.keras.layers.CuDNNGRU(self.units, return_sequences=True,
                                                    return_state=True, name='decoder')
        else:
            self.encoder = tf.keras.layers.GRU(self.units, return_sequences=True,
                                                    return_state=True, name='encoder')
            self.decoder = tf.keras.layers.GRU(self.units, return_sequences=True,
                                                    return_state=True, name='decoder')

        self.dropout = tf.keras.layers.Dropout(self.dropout_rate)

        self.fc_out = tf.keras.layers.Dense(self.output_dim, activation='relu', name='affine_out')

    def call(self, x, mask):
        
        enc_output, enc_states = self.encoder(x, initial_state=self.reset_states())
        dec_input = self.dropout(tf.concat([x, enc_output], axis=-1), training=self.training)
        dec_output, dec_states = self.decoder(dec_input, enc_states)

        x = self.fc_out(dec_output) * mask

        return x

# %% [markdown]
# ### Train Model

# %%
import trainers.tf_eager_trainer as trainer

# Run a training batch
tf.set_random_seed(231) # Set seed

# Initialise model and optimiser
model = RNN(hparams.output_dim, hparams.neurons_unit, hparams.batch_size)
optimizer = tf.train.AdamOptimizer(learning_rate = hparams.learning_rate)

# Start training run
loss, accuracy, run_time, stats = trainer.train_model(model, optimizer, dataset, hparams,
                                                      epochs=200, verbose=True, dev_dataset=dataset_val)

# Display results
print('Loss {:.4f} Accuracy {:.4f} Time {:.4f}'.format(loss * 100, accuracy * 100, run_time))

plt.figure()
for name, stat in stats.items():
    if name != 'time':
        plt.plot(stat, label=name)
plt.legend()
plt.yscale('log')
plt.show()

trainer.save_model(model, optimizer, dataset_val, hparams, 'birnn_affine_' + get_fields.replace(' ', '_'), stats=stats)
model.summary()
# Out:
# Epoch 1 Loss 0.5901 Accuracy 0.5896
# Time taken for 1 epoch 1.4926 sec
#
# Epoch 2 Loss 0.0890 Accuracy 0.0884
# Time taken for 1 epoch 0.5240 sec
#
# Epoch 3 Loss 0.0388 Accuracy 0.0382
# Time taken for 1 epoch 0.5128 sec
#
# Epoch 4 Loss 0.0138 Accuracy 0.0132
# Time taken for 1 epoch 0.5152 sec
#
# Epoch 5 Loss 0.0081 Accuracy 0.0075
# Time taken for 1 epoch 0.5279 sec
#
# Epoch 6 Loss 0.0071 Accuracy 0.0065
# Time taken for 1 epoch 0.5236 sec
#
# Epoch 7 Loss 0.0074 Accuracy 0.0067
# Time taken for 1 epoch 0.5221 sec
#
# Epoch 8 Loss 0.0071 Accuracy 0.0064
# Time taken for 1 epoch 0.5207 sec
#
# Epoch 9 Loss 0.0065 Accuracy 0.0059
# Time taken for 1 epoch 0.5128 sec
#
# Epoch 10 Loss 0.0063 Accuracy 0.0056
# Time taken for 1 epoch 0.5100 sec
#
# Epoch 11 Loss 0.0061 Accuracy 0.0055
# Time taken for 1 epoch 0.5143 sec
#
# Epoch 12 Loss 0.0063 Accuracy 0.0057
# Time taken for 1 epoch 0.5192 sec
#
# Epoch 13 Loss 0.0066 Accuracy 0.0060
# Time taken for 1 epoch 0.5234 sec
#
# Epoch 14 Loss 0.0067 Accuracy 0.0061
# Time taken for 1 epoch 0.5192 sec
#
# Epoch 15 Loss 0.0069 Accuracy 0.0062
# Time taken for 1 epoch 0.5428 sec
#
# Epoch 16 Loss 0.0069 Accuracy 0.0063
# Time taken for 1 epoch 0.5391 sec
#
# Epoch 17 Loss 0.0070 Accuracy 0.0064
# Time taken for 1 epoch 0.5452 sec
#
# Epoch 18 Loss 0.0069 Accuracy 0.0063
# Time taken for 1 epoch 0.5373 sec
#
# Epoch 19 Loss 0.0070 Accuracy 0.0064
# Time taken for 1 epoch 0.5242 sec
#
# Epoch 20 Loss 0.0071 Accuracy 0.0065
# Time taken for 1 epoch 0.5319 sec
#
# Epoch 21 Loss 0.0071 Accuracy 0.0065
# Time taken for 1 epoch 0.5505 sec
#
# Epoch 22 Loss 0.0071 Accuracy 0.0065
# Time taken for 1 epoch 0.5302 sec
#
# Epoch 23 Loss 0.0073 Accuracy 0.0067
# Time taken for 1 epoch 0.5418 sec
#
# Epoch 24 Loss 0.0075 Accuracy 0.0069
# Time taken for 1 epoch 0.5314 sec
#
# Epoch 25 Loss 0.0076 Accuracy 0.0069
# Time taken for 1 epoch 0.5346 sec
#
# Epoch 26 Loss 0.0076 Accuracy 0.0070
# Time taken for 1 epoch 0.5358 sec
#
# Epoch 27 Loss 0.0076 Accuracy 0.0070
# Time taken for 1 epoch 0.5408 sec
#
# Epoch 28 Loss 0.0075 Accuracy 0.0069
# Time taken for 1 epoch 0.5406 sec
#
# Epoch 29 Loss 0.0075 Accuracy 0.0068
# Time taken for 1 epoch 0.5252 sec
#
# Epoch 30 Loss 0.0073 Accuracy 0.0067
# Time taken for 1 epoch 0.5246 sec
#
# Epoch 31 Loss 0.0071 Accuracy 0.0065
# Time taken for 1 epoch 0.5344 sec
#
# Epoch 32 Loss 0.0070 Accuracy 0.0064
# Time taken for 1 epoch 0.5245 sec
#
# Epoch 33 Loss 0.0067 Accuracy 0.0061
# Time taken for 1 epoch 0.5262 sec
#
# Epoch 34 Loss 0.0065 Accuracy 0.0059
# Time taken for 1 epoch 0.5490 sec
#
# Epoch 35 Loss 0.0063 Accuracy 0.0057
# Time taken for 1 epoch 0.5370 sec
#
# Epoch 36 Loss 0.0061 Accuracy 0.0054
# Time taken for 1 epoch 0.5395 sec
#
# Epoch 37 Loss 0.0060 Accuracy 0.0053
# Time taken for 1 epoch 0.5250 sec
#
# Epoch 38 Loss 0.0058 Accuracy 0.0052
# Time taken for 1 epoch 0.5398 sec
#
# Epoch 39 Loss 0.0057 Accuracy 0.0050
# Time taken for 1 epoch 0.5367 sec
#
# Epoch 40 Loss 0.0055 Accuracy 0.0049
# Time taken for 1 epoch 0.5289 sec
#
# Epoch 41 Loss 0.0054 Accuracy 0.0048
# Time taken for 1 epoch 0.5091 sec
#
# Epoch 42 Loss 0.0053 Accuracy 0.0047
# Time taken for 1 epoch 0.5217 sec
#
# Epoch 43 Loss 0.0052 Accuracy 0.0046
# Time taken for 1 epoch 0.5205 sec
#
# Epoch 44 Loss 0.0052 Accuracy 0.0046
# Time taken for 1 epoch 0.5253 sec
#
# Epoch 45 Loss 0.0050 Accuracy 0.0044
# Time taken for 1 epoch 0.5260 sec
#
# Epoch 46 Loss 0.0050 Accuracy 0.0044
# Time taken for 1 epoch 0.5229 sec
#
# Epoch 47 Loss 0.0050 Accuracy 0.0044
# Time taken for 1 epoch 0.5225 sec
#
# Epoch 48 Loss 0.0049 Accuracy 0.0043
# Time taken for 1 epoch 0.5168 sec
#
# Epoch 49 Loss 0.0048 Accuracy 0.0042
# Time taken for 1 epoch 0.5164 sec
#
# Epoch 50 Loss 0.0047 Accuracy 0.0041
# Time taken for 1 epoch 0.6096 sec
#
# Epoch 51 Loss 0.0046 Accuracy 0.0040
# Time taken for 1 epoch 0.6238 sec
#
# Epoch 52 Loss 0.0045 Accuracy 0.0039
# Time taken for 1 epoch 0.6063 sec
#
# Epoch 53 Loss 0.0044 Accuracy 0.0038
# Time taken for 1 epoch 0.6115 sec
#
# Epoch 54 Loss 0.0043 Accuracy 0.0037
# Time taken for 1 epoch 0.6168 sec
#
# Epoch 55 Loss 0.0043 Accuracy 0.0037
# Time taken for 1 epoch 0.6007 sec
#
# Epoch 56 Loss 0.0043 Accuracy 0.0037
# Time taken for 1 epoch 0.6090 sec
#
# Epoch 57 Loss 0.0042 Accuracy 0.0037
# Time taken for 1 epoch 0.6206 sec
#
# Epoch 58 Loss 0.0042 Accuracy 0.0036
# Time taken for 1 epoch 0.5688 sec
#
# Epoch 59 Loss 0.0040 Accuracy 0.0035
# Time taken for 1 epoch 0.5156 sec
#
# Epoch 60 Loss 0.0040 Accuracy 0.0034
# Time taken for 1 epoch 0.5161 sec
#
# Epoch 61 Loss 0.0039 Accuracy 0.0034
# Time taken for 1 epoch 0.5154 sec
#
# Epoch 62 Loss 0.0039 Accuracy 0.0033
# Time taken for 1 epoch 0.5246 sec
#
# Epoch 63 Loss 0.0039 Accuracy 0.0033
# Time taken for 1 epoch 0.5168 sec
#
# Epoch 64 Loss 0.0039 Accuracy 0.0033
# Time taken for 1 epoch 0.5162 sec
#
# Epoch 65 Loss 0.0038 Accuracy 0.0032
# Time taken for 1 epoch 0.5183 sec
#
# Epoch 66 Loss 0.0037 Accuracy 0.0031
# Time taken for 1 epoch 0.5297 sec
#
# Epoch 67 Loss 0.0036 Accuracy 0.0030
# Time taken for 1 epoch 0.5350 sec
#
# Epoch 68 Loss 0.0036 Accuracy 0.0030
# Time taken for 1 epoch 0.5231 sec
#
# Epoch 69 Loss 0.0035 Accuracy 0.0030
# Time taken for 1 epoch 0.5328 sec
#
# Epoch 70 Loss 0.0036 Accuracy 0.0030
# Time taken for 1 epoch 0.5256 sec
#
# Epoch 71 Loss 0.0035 Accuracy 0.0029
# Time taken for 1 epoch 0.5200 sec
#
# Epoch 72 Loss 0.0035 Accuracy 0.0029
# Time taken for 1 epoch 0.5318 sec
#
# Epoch 73 Loss 0.0035 Accuracy 0.0029
# Time taken for 1 epoch 0.5202 sec
#
# Epoch 74 Loss 0.0034 Accuracy 0.0028
# Time taken for 1 epoch 0.5343 sec
#
# Epoch 75 Loss 0.0033 Accuracy 0.0027
# Time taken for 1 epoch 0.5225 sec
#
# Epoch 76 Loss 0.0032 Accuracy 0.0027
# Time taken for 1 epoch 0.5309 sec
#
# Epoch 77 Loss 0.0032 Accuracy 0.0027
# Time taken for 1 epoch 0.5221 sec
#
# Epoch 78 Loss 0.0032 Accuracy 0.0026
# Time taken for 1 epoch 0.5313 sec
#
# Epoch 79 Loss 0.0032 Accuracy 0.0026
# Time taken for 1 epoch 0.5244 sec
#
# Epoch 80 Loss 0.0031 Accuracy 0.0026
# Time taken for 1 epoch 0.5246 sec
#
# Epoch 81 Loss 0.0031 Accuracy 0.0025
# Time taken for 1 epoch 0.5243 sec
#
# Epoch 82 Loss 0.0031 Accuracy 0.0025
# Time taken for 1 epoch 0.5257 sec
#
# Epoch 83 Loss 0.0030 Accuracy 0.0025
# Time taken for 1 epoch 0.5214 sec
#
# Epoch 84 Loss 0.0030 Accuracy 0.0024
# Time taken for 1 epoch 0.5347 sec
#
# Epoch 85 Loss 0.0029 Accuracy 0.0024
# Time taken for 1 epoch 0.5218 sec
#
# Epoch 86 Loss 0.0029 Accuracy 0.0023
# Time taken for 1 epoch 0.5356 sec
#
# Epoch 87 Loss 0.0029 Accuracy 0.0023
# Time taken for 1 epoch 0.5322 sec
#
# Epoch 88 Loss 0.0029 Accuracy 0.0023
# Time taken for 1 epoch 0.5184 sec
#
# Epoch 89 Loss 0.0028 Accuracy 0.0022
# Time taken for 1 epoch 0.5328 sec
#
# Epoch 90 Loss 0.0028 Accuracy 0.0022
# Time taken for 1 epoch 0.5526 sec
#
# Epoch 91 Loss 0.0027 Accuracy 0.0022
# Time taken for 1 epoch 0.5333 sec
#
# Epoch 92 Loss 0.0027 Accuracy 0.0022
# Time taken for 1 epoch 0.5164 sec
#
# Epoch 93 Loss 0.0027 Accuracy 0.0022
# Time taken for 1 epoch 0.5250 sec
#
# Epoch 94 Loss 0.0027 Accuracy 0.0021
# Time taken for 1 epoch 0.5179 sec
#
# Epoch 95 Loss 0.0027 Accuracy 0.0021
# Time taken for 1 epoch 0.5265 sec
#
# Epoch 96 Loss 0.0026 Accuracy 0.0021
# Time taken for 1 epoch 0.5218 sec
#
# Epoch 97 Loss 0.0026 Accuracy 0.0020
# Time taken for 1 epoch 0.5173 sec
#
# Epoch 98 Loss 0.0026 Accuracy 0.0020
# Time taken for 1 epoch 0.5229 sec
#
# Epoch 99 Loss 0.0025 Accuracy 0.0020
# Time taken for 1 epoch 0.5281 sec
#
# Epoch 100 Loss 0.0025 Accuracy 0.0019
# Time taken for 1 epoch 0.5235 sec
#
# Epoch 101 Loss 0.0025 Accuracy 0.0019
# Time taken for 1 epoch 0.5398 sec
#
# Epoch 102 Loss 0.0025 Accuracy 0.0019
# Time taken for 1 epoch 0.5376 sec
#
# Epoch 103 Loss 0.0024 Accuracy 0.0019
# Time taken for 1 epoch 0.5373 sec
#
# Epoch 104 Loss 0.0024 Accuracy 0.0019
# Time taken for 1 epoch 0.5424 sec
#
# Epoch 105 Loss 0.0024 Accuracy 0.0019
# Time taken for 1 epoch 0.5259 sec
#
# Epoch 106 Loss 0.0024 Accuracy 0.0018
# Time taken for 1 epoch 0.5337 sec
#
# Epoch 107 Loss 0.0023 Accuracy 0.0018
# Time taken for 1 epoch 0.5222 sec
#
# Epoch 108 Loss 0.0023 Accuracy 0.0018
# Time taken for 1 epoch 0.5162 sec
#
# Epoch 109 Loss 0.0023 Accuracy 0.0017
# Time taken for 1 epoch 0.5255 sec
#
# Epoch 110 Loss 0.0022 Accuracy 0.0017
# Time taken for 1 epoch 0.5323 sec
#
# Epoch 111 Loss 0.0022 Accuracy 0.0017
# Time taken for 1 epoch 0.5388 sec
#
# Epoch 112 Loss 0.0022 Accuracy 0.0017
# Time taken for 1 epoch 0.5231 sec
#
# Epoch 113 Loss 0.0022 Accuracy 0.0016
# Time taken for 1 epoch 0.5191 sec
#
# Epoch 114 Loss 0.0022 Accuracy 0.0016
# Time taken for 1 epoch 0.5314 sec
# Epoch 115 Loss 0.0022 Accuracy 0.0016
# Time taken for 1 epoch 0.5214 sec
#
# Epoch 116 Loss 0.0021 Accuracy 0.0016
# Time taken for 1 epoch 0.5405 sec
#
# Epoch 117 Loss 0.0021 Accuracy 0.0016
# Time taken for 1 epoch 0.5366 sec
#
# Epoch 118 Loss 0.0021 Accuracy 0.0016
# Time taken for 1 epoch 0.5226 sec
#
# Epoch 119 Loss 0.0021 Accuracy 0.0015
# Time taken for 1 epoch 0.5192 sec
#
# Epoch 120 Loss 0.0021 Accuracy 0.0015
# Time taken for 1 epoch 0.5217 sec
#
# Epoch 121 Loss 0.0021 Accuracy 0.0015
# Time taken for 1 epoch 0.5223 sec
#
# Epoch 122 Loss 0.0020 Accuracy 0.0015
# Time taken for 1 epoch 0.5422 sec
#
# Epoch 123 Loss 0.0020 Accuracy 0.0015
# Time taken for 1 epoch 0.5338 sec
#
# Epoch 124 Loss 0.0020 Accuracy 0.0015
# Time taken for 1 epoch 0.5288 sec
#
# Epoch 125 Loss 0.0020 Accuracy 0.0014
# Time taken for 1 epoch 0.5107 sec
#
# Epoch 126 Loss 0.0020 Accuracy 0.0014
# Time taken for 1 epoch 0.5228 sec
#
# Epoch 127 Loss 0.0020 Accuracy 0.0014
# Time taken for 1 epoch 0.5328 sec
#
# Epoch 128 Loss 0.0019 Accuracy 0.0014
# Time taken for 1 epoch 0.5363 sec
#
# Epoch 129 Loss 0.0019 Accuracy 0.0014
# Time taken for 1 epoch 0.5293 sec
#
# Epoch 130 Loss 0.0019 Accuracy 0.0014
# Time taken for 1 epoch 0.5159 sec
#
# Epoch 131 Loss 0.0019 Accuracy 0.0014
# Time taken for 1 epoch 0.5169 sec
#
# Epoch 132 Loss 0.0019 Accuracy 0.0014
# Time taken for 1 epoch 0.5293 sec
#
# Epoch 133 Loss 0.0019 Accuracy 0.0013
# Time taken for 1 epoch 0.5448 sec
#
# Epoch 134 Loss 0.0018 Accuracy 0.0013
# Time taken for 1 epoch 0.5291 sec
#
# Epoch 135 Loss 0.0018 Accuracy 0.0013
# Time taken for 1 epoch 0.5174 sec
#
# Epoch 136 Loss 0.0018 Accuracy 0.0013
# Time taken for 1 epoch 0.5153 sec
#
# Epoch 137 Loss 0.0018 Accuracy 0.0013
# Time taken for 1 epoch 0.5213 sec
#
# Epoch 138 Loss 0.0018 Accuracy 0.0013
# Time taken for 1 epoch 0.5154 sec
#
# Epoch 139 Loss 0.0018 Accuracy 0.0013
# Time taken for 1 epoch 0.5195 sec
#
# Epoch 140 Loss 0.0018 Accuracy 0.0012
# Time taken for 1 epoch 0.5229 sec
#
# Epoch 141 Loss 0.0017 Accuracy 0.0012
# Time taken for 1 epoch 0.5215 sec
#
# Epoch 142 Loss 0.0017 Accuracy 0.0012
# Time taken for 1 epoch 0.5188 sec
#
# Epoch 143 Loss 0.0017 Accuracy 0.0012
# Time taken for 1 epoch 0.5253 sec
#
# Epoch 144 Loss 0.0017 Accuracy 0.0012
# Time taken for 1 epoch 0.5193 sec
#
# Epoch 145 Loss 0.0017 Accuracy 0.0012
# Time taken for 1 epoch 0.5179 sec
#
# Epoch 146 Loss 0.0017 Accuracy 0.0012
# Time taken for 1 epoch 0.5193 sec
#
# Epoch 147 Loss 0.0017 Accuracy 0.0012
# Time taken for 1 epoch 0.5158 sec
#
# Epoch 148 Loss 0.0017 Accuracy 0.0011
# Time taken for 1 epoch 0.5144 sec
#
# Epoch 149 Loss 0.0017 Accuracy 0.0011
# Time taken for 1 epoch 0.5210 sec
#
# Epoch 150 Loss 0.0017 Accuracy 0.0011
# Time taken for 1 epoch 0.5164 sec
#
# Epoch 151 Loss 0.0016 Accuracy 0.0011
# Time taken for 1 epoch 0.5239 sec
#
# Epoch 152 Loss 0.0016 Accuracy 0.0011
# Time taken for 1 epoch 0.5475 sec
#
# Epoch 153 Loss 0.0016 Accuracy 0.0011
# Time taken for 1 epoch 0.5324 sec
#
# Epoch 154 Loss 0.0016 Accuracy 0.0011
# Time taken for 1 epoch 0.5483 sec
#
# Epoch 155 Loss 0.0016 Accuracy 0.0011
# Time taken for 1 epoch 0.5664 sec
#
# Epoch 156 Loss 0.0016 Accuracy 0.0011
# Time taken for 1 epoch 0.5491 sec
#
# Epoch 157 Loss 0.0016 Accuracy 0.0011
# Time taken for 1 epoch 0.5432 sec
#
# Epoch 158 Loss 0.0016 Accuracy 0.0011
# Time taken for 1 epoch 0.5430 sec
#
# Epoch 159 Loss 0.0016 Accuracy 0.0011
# Time taken for 1 epoch 0.5487 sec
#
# Epoch 160 Loss 0.0016 Accuracy 0.0010
# Time taken for 1 epoch 0.5689 sec
#
# Epoch 161 Loss 0.0015 Accuracy 0.0010
# Time taken for 1 epoch 0.5518 sec
#
# Epoch 162 Loss 0.0015 Accuracy 0.0010
# Time taken for 1 epoch 0.5523 sec
#
# Epoch 163 Loss 0.0015 Accuracy 0.0010
# Time taken for 1 epoch 0.5489 sec
#
# Epoch 164 Loss 0.0015 Accuracy 0.0010
# Time taken for 1 epoch 0.5505 sec
#
# Epoch 165 Loss 0.0015 Accuracy 0.0010
# Time taken for 1 epoch 0.5423 sec
#
# Epoch 166 Loss 0.0015 Accuracy 0.0010
# Time taken for 1 epoch 0.5486 sec
#
# Epoch 167 Loss 0.0015 Accuracy 0.0010
# Time taken for 1 epoch 0.5318 sec
#
# Epoch 168 Loss 0.0015 Accuracy 0.0010
# Time taken for 1 epoch 0.5531 sec
#
# Epoch 169 Loss 0.0015 Accuracy 0.0010
# Time taken for 1 epoch 0.5467 sec
#
# Epoch 170 Loss 0.0015 Accuracy 0.0009
# Time taken for 1 epoch 0.5458 sec
#
# Epoch 171 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5384 sec
#
# Epoch 172 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5211 sec
#
# Epoch 173 Loss 0.0015 Accuracy 0.0010
# Time taken for 1 epoch 0.5334 sec
#
# Epoch 174 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5612 sec
#
# Epoch 175 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5338 sec
#
# Epoch 176 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5289 sec
#
# Epoch 177 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5254 sec
#
# Epoch 178 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5235 sec
#
# Epoch 179 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5220 sec
#
# Epoch 180 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5410 sec
#
# Epoch 181 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5227 sec
#
# Epoch 182 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5341 sec
#
# Epoch 183 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5465 sec
#
# Epoch 184 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5353 sec
#
# Epoch 185 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5321 sec
#
# Epoch 186 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5208 sec
#
# Epoch 187 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5275 sec
#
# Epoch 188 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5226 sec
#
# Epoch 189 Loss 0.0014 Accuracy 0.0008
# Time taken for 1 epoch 0.5329 sec
#
# Epoch 190 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5206 sec
#
# Epoch 191 Loss 0.0014 Accuracy 0.0009
# Time taken for 1 epoch 0.5110 sec
#
# Epoch 192 Loss 0.0014 Accuracy 0.0008
# Time taken for 1 epoch 0.5517 sec
#
# Epoch 193 Loss 0.0013 Accuracy 0.0008
# Time taken for 1 epoch 0.5309 sec
#
# Epoch 194 Loss 0.0013 Accuracy 0.0008
# Time taken for 1 epoch 0.5351 sec
#
# Epoch 195 Loss 0.0013 Accuracy 0.0008
# Time taken for 1 epoch 0.5473 sec
#
# Epoch 196 Loss 0.0013 Accuracy 0.0008
# Time taken for 1 epoch 0.5182 sec
#
# Epoch 197 Loss 0.0013 Accuracy 0.0008
# Time taken for 1 epoch 0.5240 sec
#
# Epoch 198 Loss 0.0013 Accuracy 0.0008
# Time taken for 1 epoch 0.5184 sec
#
# Epoch 199 Loss 0.0013 Accuracy 0.0008
# Time taken for 1 epoch 0.5212 sec
#
# Epoch 200 Loss 0.0013 Accuracy 0.0008
# Time taken for 1 epoch 0.5320 sec
#
# Loss 0.0013 Accuracy 0.0008 Time 107.5203
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (CuDNNGRU)           multiple                  3744
# _________________________________________________________________
# decoder (CuDNNGRU)           multiple                  6816
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# affine_out (Dense)           multiple                  33
# =================================================================
# Total params: 10,593
# Trainable params: 10,593
# Non-trainable params: 0
# _________________________________________________________________

# %%
# show all sequences
# Select target sequence to show
TARGET_INDEX = 0

# Create forecast and rescale data
inp, target, mask, x_max = next(iter(dataset))
model.training = False
forecast = model(inp, mask)
forecast *= tf.keras.backend.expand_dims(x_max)
target   *= tf.keras.backend.expand_dims(x_max)
inp = np.reshape(inp, [hparams.batch_size, hparams.in_seq_len, hparams.input_dim, hparams.input_channels])
inp *= np.reshape(x_max, [hparams.batch_size,1,1,-1])

# Plot target sequence
plt.figure(figsize=(16,12))
plt.plot(np.squeeze(forecast[TARGET_INDEX,:,0]), label='forecast')
plt.plot(np.squeeze(target[TARGET_INDEX,:,0]), label='target')
plt.plot(np.mean(inp, axis=2)[TARGET_INDEX,:,0], 'bo', label='5 period average')
for i in range(hparams.input_dim):
    plt.plot(np.array(inp)[TARGET_INDEX,:,i,0], '--', label='%i periods prior' % (5-i))
plt.legend()
plt.show()

# Plot specimen predictions
plt.figure(figsize=(16,16))
for i in range(0,800,8):
    ax = plt.subplot(10,10,i/8+1)
    ax.plot(np.squeeze(forecast[i]), label='forecast')
    ax.plot(np.squeeze(target[i]), label='target')
plt.show()

# %% [markdown]
# ### Test Hyperparameters

# %%
np.random.seed(231)
models = []

#for nodes in np.floor(2 ** np.arange(3,9)):
#for lr in np.random.uniform(-8, -1, 10):
for lr in range(-8, 0, 1):
    lr /= 2

    # Run a training batch
    tf.set_random_seed(231) # Set seed

    # Initialise model and optimiser
    model_ = RNN(hparams.output_dim, hparams.neurons_unit, hparams.batch_size)
    optimizer_ = tf.train.AdamOptimizer(learning_rate = 10 ** lr)

    # Start training run
    loss, accuracy, run_time, stats = trainer.train_model(model_, optimizer_, dataset, hparams,
                                                          epochs=20, verbose=False, dev_dataset=dataset_val)
    print('Learning Rate {:.4f} Loss {:.4f} Accuracy {:.4f} Time {:.1f}'.format(lr, loss*100, accuracy * 100, run_time))
    
    models.append(model_)
# Out:
# Learning Rate -4.0000 Loss 0.0329 Accuracy 0.0324 Time 9.9
# Learning Rate -3.5000 Loss 0.0190 Accuracy 0.0185 Time 10.5
# Learning Rate -3.0000 Loss 0.0097 Accuracy 0.0092 Time 10.8
# Learning Rate -2.5000 Loss 0.0047 Accuracy 0.0042 Time 10.6
# Learning Rate -2.0000 Loss 0.0071 Accuracy 0.0065 Time 10.6
# Learning Rate -1.5000 Loss 2.7375 Accuracy 2.7345 Time 10.7
# Learning Rate -1.0000 Loss 0.0640 Accuracy 0.0492 Time 11.7
# Learning Rate -0.5000 Loss 0.1437 Accuracy 0.0238 Time 10.8

# %% [markdown]
# ## Test Model Accuracy

# %%
model_accuracy = []

# %%
for name, dataset_eval in([['Train', dataset], ['Test', dataset_test]]):
    print(name + ' Results')
    total_accuracy = []
    x_variance = x_var(hparams, mode=get_fields)

    for i, (inp, target, mask, x_max) in enumerate(dataset_eval):
        forecast = model(inp, mask)

        accuracy = tf.squeeze(forecast - target) * x_max
        accuracy = accuracy ** 2 / x_variance
        accuracy = np.mean(accuracy, axis=0)

        total_accuracy.append(accuracy)

    model_accuracy.append((hparams.in_seq_len, np.mean(total_accuracy, axis=0)))

    print('Total RSE Accuracy: %.4f' % np.mean(total_accuracy))
    print('Total MSE Accuracy: %.4f' % (np.mean(total_accuracy) * x_variance))
    plt.plot(np.mean(total_accuracy, axis=0))
    plt.show()
# Out:
# Train Results
# Total RSE Accuracy: 0.7705
# Total MSE Accuracy: 0.0678
# Test Results
# Total RSE Accuracy: 0.7064
# Total MSE Accuracy: 0.0621
